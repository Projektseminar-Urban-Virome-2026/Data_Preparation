# %% [markdown]
# # Inspection and Cleaning of the Data from NCBI

# %% [markdown]
# ## Imports

# %%
from pathlib import Path # Importing the Path class from the pathlib module to handle file paths
import pandas as pd # Importing the pandas library for data manipulation and analysis

# %% [markdown]
# ## Data Import

# %%
# Define the path to the CSV file containing virus information
csv_file = Path("virus_data.csv")

# Function to load virus information from the specified CSV file
def load_virus_information(source):
    return pd.read_csv(source, sep=",")

# Load the virus information into a DataFrame
df = load_virus_information(csv_file)

# Checking the DataFrame to ensure it contains the expected columns and data
print("Total number of samples in the dataset:", len(df))
print("\n================================\n")

print(df.head())  # Shows the first five rows when the script is executed.
# Out:
# /var/folders/zj/bjdnzpxn1n7_54r06q1k3gg80000gn/T/ipykernel_5669/184199527.py:6: DtypeWarning: Columns (3,4,6,12,13,14,15,16,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(source, sep=",")
# Total number of samples in the dataset: 27857749
#
# ================================
#
#   Nucleotide Accession  Species Taxonomy Id        Species Name  Virus Genus  \
# 0          NC_135454.1              3025750  Human circovirus 1   Circovirus
# 1          NC_135454.1              3025750  Human circovirus 1   Circovirus
# 2          NC_135452.1              3432268    Satomivirus wayo  Satomivirus
# 3          NC_135452.1              3432268    Satomivirus wayo  Satomivirus
# 4          NC_135452.1              3432268    Satomivirus wayo  Satomivirus
#
#      Virus Family  Nucleotide Length Isolate Name Sequence Type  \
# 0    Circoviridae               2021        Paris        RefSeq
# 1    Circoviridae               2021        Paris        RefSeq
# 2  Konodaiviridae              57601   1827_77749        RefSeq
# 3  Konodaiviridae              57601   1827_77749        RefSeq
# 4  Konodaiviridae              57601   1827_77749        RefSeq
#
#    Nuc Completeness    Geo Location  Host Name  Host Taxonomy ID  \
# 0               NaN  Europe; France        NaN              9606
# 1               NaN  Europe; France        NaN              9606
# 2               NaN     Asia; Japan        NaN              9606
# 3               NaN     Asia; Japan        NaN              9606
# 4               NaN     Asia; Japan        NaN              9606
#
#   Collection Date   BioProject BioSample Polyprotein Name  \
# 0      2022-01-12  PRJNA485481       NaN              NaN
# 1      2022-01-12  PRJNA485481       NaN              NaN
# 2             NaN  PRJNA485481       NaN              NaN
# 3             NaN  PRJNA485481       NaN              NaN
# 4             NaN  PRJNA485481       NaN              NaN
#
#                                         Protein Name Protein Accession  \
# 0                     replication-associated protein    YP_013607440.1
# 1                                     capsid protein    YP_013607441.1
# 2                                 telomere resolvase    YP_013607359.1
# 3                                        CII protein    YP_013607360.1
# 4  membrane lipoprotein lipid attachment site pro...    YP_013607361.1
#
#    Protein Synonym    CDS Span
# 0              NaN   247..1134
# 1              NaN  1368..2012
# 2              NaN   275..1549
# 3              NaN  1995..2252
# 4              NaN  2252..2569
